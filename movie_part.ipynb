# %%
import imdb

# %%
moviesDB = imdb.IMDb()

# %%
top250 = [str(movie).rstrip("title") for movie in moviesDB.get_top250_movies()]
top250
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knigh',
#  '12 Angry Men',
#  "Schindler's Lis",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'The Good, the Bad and the Ugly',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Fight Club',
#  'Forrest Gump',
#  'Inception',
#  'The Lord of the Rings: The Two Towers',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nes",
#  'Seven Samura',
#  'Se7en',
#  'The Silence of the Lambs',
#  'City of God',
#  'Life Is Beautifu',
#  "It's a Wonderful Lif",
#  'Star Wars: Episode IV - A New Hop',
#  'Saving Private Ryan',
#  'Spirited Away',
#  'Interstellar',
#  'The Green M',
#  'Paras',
#  'Léon: The Professiona',
#  'Hara-Kir',
#  'The Usual Suspects',
#  'The Pianis',
#  'Back to the Futur',
#  'Terminator 2: Judgment Day',
#  'Psycho',
#  'Modern Times',
#  'The Lion King',
# ...

# %%
initial = input()
lst = [title for title in top250 if title[0] == initial.upper()]
lst
# Out:
# t
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knigh',
#  'The Lord of the Rings: The Return of the King',
#  'The Good, the Bad and the Ugly',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Lord of the Rings: The Two Towers',
#  'The Matrix',
#  'The Silence of the Lambs',
#  'The Green M',
#  'The Usual Suspects',
#  'The Pianis',
#  'Terminator 2: Judgment Day',
#  'The Lion King',
#  'The Departed',
#  'The Intouchables',
#  'The Prestig',
#  'The Great Dictator',
#  'The Lives of Others',
#  'The Shining',
#  'The Dark Knight Rises',
#  'Toy Story',
#  'The Hun',
#  'The Kid',
#  'The Father',
#  'Taxi Driver',
#  'The Sting',
#  'The Apartmen',
#  'Toy Story 3',
#  'To Kill a Mockingbird',
#  'The Wolf of Wall Str',
#  'The Great Escap',
#  'The Treasure of the Sierra Madr',
#  'There Will Be Blood',
#  'The Secret in Their Eyes',
#  'The Gold Rush',
#  'Three Billboards Outside Ebbing, Missour',
# ...

# %%
import pyttsx3

# %%
engine = pyttsx3.init()

# %%
engine.setProperty('rate', 175)     # setting up new voice rate
volume = engine.getProperty('volume')   #getting to know current volume level (min=0 and max=1)
engine.setProperty('volume',2) 
engine.say(list[:5])
engine.runAndWait()

# %%
import cv2

# %%
import numpy as np

# %%
blackboard = np.zeros((512, 1000), np.uint8)

# %%
import time

# %%
while True:
    cv2.putText(blackboard, "WE RECOMMEND YOU:", (100,100), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2) 
    cv2.putText(blackboard, lst[0], (100,150), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2) 
    cv2.putText(blackboard, lst[1], (100,200), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2) 
    cv2.putText(blackboard, lst[2], (100,250), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2) 
    cv2.putText(blackboard, lst[3], (100,300), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2) 
    cv2.putText(blackboard, lst[4], (100,350), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2) 

    cv2.imshow("blackboard",blackboard)
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
    
#reset blackboard
blackboard = np.zeros((512,1000), np.uint8)
cv2.destroyAllWindows()
